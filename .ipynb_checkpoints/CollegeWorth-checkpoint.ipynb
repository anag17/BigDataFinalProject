# %%
import pandas as pd
df = pd.read_csv('CollegeTuitionData.csv', encoding = "ISO-8859-1", header = None)
tuitionData = pd.concat([df[0], df[4]], axis=1)
df2 = pd.read_csv('salaries-by-college-type.csv', encoding = "ISO-8859-1", header = None)
df2 = df2.drop(0)
salaryData = pd.concat([df2[0], df2[1], df2[2]], axis=1)
salaryData
# Out:
#                                                      0             1  \
# 1                                      Amherst College  Liberal Arts
# 2                         Appalachian State University         State
# 3                       Arizona State University (ASU)         Party
# 4                       Arizona State University (ASU)         State
# 5                      Arkansas State University (ASU)         State
# 6                                    Auburn University         State
# 7                         Austin Peay State University         State
# 8                          Ball State University (BSU)         State
# 9                                        Bates College  Liberal Arts
# 10                               Binghamton University         State
# 11                        Black Hills State University         State
# 12                        Boise State University (BSU)         State
# 13                                     Bowdoin College  Liberal Arts
# ...

# %%
import re
colleges = list()
tuitions = list()
salaries = list()
collegeType = list()
for row in salaryData.iterrows():
    college = row[1][0]
    college = re.sub("[\(\[].*?[\)\]]", "", college)
    for row2 in tuitionData.iterrows():
        college2 = row2[1][0]
        if (college == college2):
            print (college)
#             colleges.append(college)
#             tuitions.append(row2[1][1])
#             salaries.append(row[1][2])
#             collegeType.append(row[1][1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-f34442036ac9> in <module>()
#      11         if (college == college2):
#      12             colleges.append(college)
# ---> 13             tuitions.append(row2[1][1])
#      14             salaries.append(row[1][2])
#      15             collegeType.append(row[1][1])
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# ...

# %%
tuitionTranspose = tuitionData.transpose()
tuitionTranspose = tuitionTranspose.rename(columns=tuitionTranspose.iloc[0])
#tuitionTranspose.drop(1)
salarayTranspose = salaryData.transpose()
salarayTranspose = salarayTranspose.rename(columns=salarayTranspose.iloc[0])
#salarayTranspose.drop(1)
tuitionTranspose
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-d0a0aaf8822e> in <module>()
#       1 tuitionTranspose = tuitionData.transpose()
#       2 tuitionTranspose = tuitionTranspose.rename(columns=tuitionTranspose.iloc[0])
# ----> 3 tuitionTranspose.drop(1)
#       4 salarayTranspose = salaryData.transpose()
#       5 salarayTranspose = salarayTranspose.rename(columns=salarayTranspose.iloc[0])
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ...

# %%
df = pd.concat([tuitionTranspose, salarayTranspose], join='inner', ignore_index=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-6e103bc28203> in <module>()
# ----> 1 df = pd.concat([tuitionTranspose, salarayTranspose], join='inner', ignore_index=True)
#       2 df
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     205                        verify_integrity=verify_integrity,
#     206                        copy=copy)
# --> 207     return op.get_result()
#     208
#     209
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     405             new_data = concatenate_block_managers(
#     406                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 407                 copy=self.copy)
# ...
