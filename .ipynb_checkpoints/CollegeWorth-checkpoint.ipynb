# %%
import pandas as pd

#Get tuition data
df = pd.read_csv('CollegeTuitionData.csv', encoding = "ISO-8859-1", header = None)
tuitionData = pd.concat([df[0], df[4]], axis=1)

#Get salary data
df2 = pd.read_csv('salaries-by-college-type.csv', encoding = "ISO-8859-1", header = None)
df2 = df2.drop(0)
salaryData = pd.concat([df2[0], df2[1], df2[2]], axis=1)

#Get region data
df3 = pd.read_csv('salaries-by-region.csv', encoding = "ISO-8859-1", header = None)
df3 = df3.drop(0)
regionData = pd.concat([df3[0], df3[1], df3[2]], axis=1)

# %%
import re
colleges = list()
tuitions = list()
salaries = list()
collegeType = list()
collegeType2 = list()
regions = list()
for row in salaryData.iterrows():
    college = row[1][0]
    college = re.sub("[\(\[].*?[\)\]]", "", college)
    for row2 in tuitionData.iterrows():
        college2 = row2[1][0]
        if (college == college2):
            if (college in colleges):
                index = colleges.index(college)
                collegeType2[index] = row[1][1]
            else:
                collegeType2.append(None)
                colleges.append(college)
                tuitions.append(row2[1][4])
                salaries.append(row[1][2])
                collegeType.append(row[1][1])

# %%
def remove_dollarSign(s):
    s = re.sub('[, ]', '', s)
    return float(s[1:-1])

tuitions = [remove_dollarSign(t) for t in tuitions]
salaries = [remove_dollarSign(s) for s in salaries]

# %%
regionData = regionData.set_index(0)
collegesRegion = df3[0]
regions = list()
count = 0
for college in colleges:
    if (college in sorted(collegesRegion)):
        regions.append(regionData.loc[college][1])

# %%
collegeData = pd.DataFrame(
    {'College': colleges,
     'Tuition': tuitions,
     'Salary': salaries,
     'College Type': collegeType,
     'College Type 2': collegeType2,
     'Region': regions
    })
collegeData = collegeData.set_index('College')

# %%
jsonData = collegeData.to_json(orient='index')
jsonData
import json
with open('data.json', 'w') as outfile:
    outfile.write(jsonData)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(tuitions,salaries)
plt.show()

# %%
# %matplotlib inline
plt.bar(regions,tuitions)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-0220719fd1fe> in <module>()
#       1 get_ipython().magic('matplotlib inline')
# ----> 2 plt.bar(regions,tuitions)
#       3 plt.show()
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# /Users/juliaweingart/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in <listcomp>(.0)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
collegeData
# Out:
#                                       College Type College Type 2  \
# College
# Amherst College                       Liberal Arts           None
# Auburn University                            State           None
# Bates College                         Liberal Arts           None
# Bowdoin College                       Liberal Arts           None
# Brown University                        Ivy League           None
# Bucknell University                   Liberal Arts           None
# Clemson University                           State           None
# Colby College                         Liberal Arts           None
# Colgate University                    Liberal Arts           None
# College of the Holy Cross             Liberal Arts           None
# Colorado School of Mines               Engineering           None
# Columbia University                     Ivy League           None
# Cornell University                      Ivy League           None
# Dartmouth College                       Ivy League           None
# Davidson College                      Liberal Arts           None
# Denison University                    Liberal Arts           None
# DePauw University                     Liberal Arts           None
# Eastern Washington University                State           None
# Franklin and Marshall College         Liberal Arts           None
# George Mason University                      State           None
# Georgia Institute of Technology        Engineering           None
# Georgia State University                     State           None
# Gettysburg College                    Liberal Arts           None
# Hamilton College                      Liberal Arts           None
# Harvard University                      Ivy League           None
# Juniata College                       Liberal Arts           None
# Lafayette College                     Liberal Arts           None
# Lewis & Clark College                 Liberal Arts           None
# Middlebury College                    Liberal Arts           None
# Mount Holyoke College                 Liberal Arts           None
# Oberlin College                       Liberal Arts           None
# Ohio University                              Party          State
# Princeton University                    Ivy League           None
# Randolph-Macon College                       Party   Liberal Arts
# Reed College                          Liberal Arts           None
# Siena College                         Liberal Arts           None
# Skidmore College                      Liberal Arts           None
# Smith College                         Liberal Arts           None
# St. Olaf College                      Liberal Arts           None
# Stevens Institute of Technology        Engineering           None
# Swarthmore College                    Liberal Arts           None
